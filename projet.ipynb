# %%
import sklearn

import sklearn.datasets
# Out:
# ['calibration', 'cluster', 'covariance', 'cross_decomposition', 'datasets', 'decomposition', 'dummy', 'ensemble', 'exceptions', 'experimental', 'externals', 'feature_extraction', 'feature_selection', 'gaussian_process', 'inspection', 'isotonic', 'kernel_approximation', 'kernel_ridge', 'linear_model', 'manifold', 'metrics', 'mixture', 'model_selection', 'multiclass', 'multioutput', 'naive_bayes', 'neighbors', 'neural_network', 'pipeline', 'preprocessing', 'random_projection', 'semi_supervised', 'svm', 'tree', 'discriminant_analysis', 'impute', 'compose', 'clone', 'get_config', 'set_config', 'config_context', 'show_versions']
#
# ['clear_data_home', 'dump_svmlight_file', 'fetch_20newsgroups', 'fetch_20newsgroups_vectorized', 'fetch_lfw_pairs', 'fetch_lfw_people', 'fetch_olivetti_faces', 'fetch_species_distributions', 'fetch_california_housing', 'fetch_covtype', 'fetch_rcv1', 'fetch_kddcup99', 'fetch_openml', 'get_data_home', 'load_boston', 'load_diabetes', 'load_digits', 'load_files', 'load_iris', 'load_breast_cancer', 'load_linnerud', 'load_sample_image', 'load_sample_images', 'load_svmlight_file', 'load_svmlight_files', 'load_wine', 'make_biclusters', 'make_blobs', 'make_circles', 'make_classification', 'make_checkerboard', 'make_friedman1', 'make_friedman2', 'make_friedman3', 'make_gaussian_quantiles', 'make_hastie_10_2', 'make_low_rank_matrix', 'make_moons', 'make_multilabel_classification', 'make_regression', 'make_s_curve', 'make_sparse_coded_signal', 'make_sparse_spd_matrix', 'make_sparse_uncorrelated', 'make_spd_matrix', 'make_swiss_roll']

# %%
"""============================================
    Chargement de la base de données "iris"
============================================"""
from matplotlib import image
from matplotlib import pyplot
import imageio
from numpy import asarray
import numpy as np
from os import listdir


X_train = np.zeros((46, 2304000))


for i in range(1, 47):
    line = []
    folder_left = "C:/Users/abdou/Desktop/New folder/MMU/" + str(i) + "/left"
    folder_right = "C:/Users/abdou/Desktop/New folder/MMU/" + str(i) + "/right"

    for j in os.listdir(folder_left):
        if j.endswith('.bmp'):
            print(j)
            img = np.array(imageio.imread(folder_left + '/' + j))
            img = img.flatten()
            line.extend(img)

    for j in os.listdir(folder_right):
        if j.endswith('.bmp'):
            print(j)
            img = np.array(imageio.imread(folder_right + '/' + j))
            img = img.flatten()
            line.extend(img)
    
    line = np.array(line)
    X_train[i-1] = line
# Out:
# aeval1.bmp
# aeval2.bmp
# aeval3.bmp
# aeval4.bmp
# aeval5.bmp
# aevar1.bmp
# aevar2.bmp
# aevar3.bmp
# aevar4.bmp
# C:\Users\abdou\AppData\Local\Temp\ipykernel_10936\4284014058.py:23: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = np.array(imageio.imread(folder_left + '/' + j))
# C:\Users\abdou\AppData\Local\Temp\ipykernel_10936\4284014058.py:30: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = np.array(imageio.imread(folder_right + '/' + j))
# aevar5.bmp
# bryanl1.bmp
# bryanl2.bmp
# bryanl3.bmp
# bryanl4.bmp
# bryanl5.bmp
# bryanr1.bmp
# bryanr2.bmp
# bryanr3.bmp
# bryanr4.bmp
# bryanr5.bmp
# chingycl1.bmp
# chingycl2.bmp
# chingycl3.bmp
# chingycl4.bmp
# chingycl5.bmp
# chingycr1.bmp
# chingycr2.bmp
# chingycr3.bmp
# chingycr4.bmp
# chingycr5.bmp
# sitil5.bmp
# sitir1.bmp
# sitir2.bmp
# sitir3.bmp
# sitir4.bmp
# sitir5.bmp
# suzailil1.bmp
# suzailil2.bmp
# suzailil3.bmp
# suzailil4.bmp
# suzailil5.bmp
# suzailir1.bmp
# suzailir2.bmp
# suzailir3.bmp
# suzailir4.bmp
# suzailir5.bmp
# tanwnl1.bmp
# tanwnl2.bmp
# tanwnl3.bmp
# tanwnl4.bmp
# tanwnl5.bmp
# tanwnr1.bmp
# tanwnr2.bmp
# tanwnr3.bmp
# tanwnr4.bmp
# tanwnr5.bmp
# thomasl1.bmp
# thomasl2.bmp
# thomasl3.bmp
# thomasl4.bmp
# thomasl5.bmp
# thomasr1.bmp
# thomasr2.bmp
# thomasr3.bmp
# thomasr4.bmp
# thomasr5.bmp
# tickl1.bmp
# tickl2.bmp
# tickl3.bmp
# tickl4.bmp
# tickl5.bmp
# tickr1.bmp
# tickr2.bmp
# tickr3.bmp
# tickr4.bmp
# tickr5.bmp
# tingcyl1.bmp
# tingcyl2.bmp
# tingcyl3.bmp
# tingcyl4.bmp
# tingcyl5.bmp
# tingcyr1.bmp
# tingcyr2.bmp
# tingcyr3.bmp
# tingcyr4.bmp
# tingcyr5.bmp
# tonghll1.bmp
# tonghll2.bmp
# tonghll3.bmp
# tonghll4.bmp
# tonghll5.bmp
# tonghlr1.bmp
# tonghlr2.bmp
# tonghlr3.bmp
# tonghlr4.bmp
# tonghlr5.bmp
# vimalal1.bmp
# vimalal2.bmp
# vimalal3.bmp
# vimalal4.bmp
# vimalal5.bmp
# vimalar1.bmp
# vimalar2.bmp
# vimalar3.bmp
# vimalar4.bmp
# vimalar5.bmp
# weecml1.bmp
# weecml2.bmp
# weecml3.bmp
# weecml4.bmp
# weecml5.bmp
# weecmr1.bmp
# weecmr2.bmp
# weecmr3.bmp
# weecmr4.bmp
# weecmr5.bmp
# winl1.bmp
# winl2.bmp
# winl3.bmp
# winl4.bmp
# winl5.bmp
# winr1.bmp
# winr2.bmp
# winr3.bmp
# winr4.bmp
# winr5.bmp
# yannl1.bmp
# yannl2.bmp
# yannl3.bmp
# yannl4.bmp
# yannl5.bmp
# yannr1.bmp
# yannr2.bmp
# yannr3.bmp
# yannr4.bmp
# yannr5.bmp
# zaridahl1.bmp
# zaridahl2.bmp
# zaridahl3.bmp
# zaridahl4.bmp
# zaridahl5.bmp
# zaridahr1.bmp
# zaridahr2.bmp
# zaridahr3.bmp
# zaridahr4.bmp
# zaridahr5.bmp
# zulaikahl1.bmp
# zulaikahl2.bmp
# zulaikahl3.bmp
# zulaikahl4.bmp
# zulaikahl5.bmp
# zulaikahr1.bmp
# zulaikahr2.bmp
# zulaikahr3.bmp
# zulaikahr4.bmp
# zulaikahr5.bmp

# %%
"""
Refait ce travail pour d'autre bases de données
"""
X_train = X_train.astype(int)
print(X_train)

# img = np.array(X_train[0][:230400]).astype(int)

# print(img)

pyplot.imshow(X_train[0][:230400].reshape(240,320,3), interpolation="nearest")
pyplot.show()
# Out:
# [[248 248 248 ...   8   4   8]
#  [248 248 248 ...   8   4   0]
#  [176 180 176 ...   0   4   8]
#  ...
#  [176 180 176 ...   8   4   8]
#  [200 208 200 ...   8   4   8]
#  [224 232 224 ...   8   4   8]]
